# %% [markdown]
# Data Wrangling: changing the format of the data so it is better for analysis

# %%
import pandas as pd
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/autos/imports-85.data"

# %%
df = pd.read_csv(url, header= None)

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns = headers

#instead of using df.columns = headers we can use this code df = pd.read_csv(filename, names = headers)

# %%
import numpy as np

# %%
#first let identify missing values
missing_data = df.isnull()
missing_data.head()
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False               True  False      False       False         False
# 1      False               True  False      False       False         False
# 2      False               True  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False              False  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  fuel-system  \
# 0       False         False            False       False  ...        False
# 1       False         False            False       False  ...        False
# 2       False         False            False       False  ...        False
# 3       False         False            False       False  ...        False
# 4       False         False            False       False  ...        False
#
# ...

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# symboling
# False    201
# Name: symboling, dtype: int64
#
# normalized-losses
# False    164
# True      37
# Name: normalized-losses, dtype: int64
#
# make
# False    201
# Name: make, dtype: int64
#
# fuel-type
# False    201
# Name: fuel-type, dtype: int64
#
# aspiration
# False    201
# Name: aspiration, dtype: int64
#
# num-of-doors
# False    199
# True       2
# Name: num-of-doors, dtype: int64
#
# body-style
# False    201
# Name: body-style, dtype: int64
#
# drive-wheels
# False    201
# Name: drive-wheels, dtype: int64
#
# engine-location
# False    201
# Name: engine-location, dtype: int64
#
# wheel-base
# False    201
# Name: wheel-base, dtype: int64
#
# length
# False    201
# Name: length, dtype: int64
#
# width
# False    201
# Name: width, dtype: int64
#
# height
# False    201
# Name: height, dtype: int64
#
# curb-weight
# False    201
# Name: curb-weight, dtype: int64
#
# engine-type
# False    201
# Name: engine-type, dtype: int64
#
# num-of-cylinders
# ...

# %%
df= df.replace("?",np.nan)

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            3               NaN  alfa-romero       gas        std
# 2            1               NaN  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
#because price is the outcome the best option for dealing with missing values of price is to remove the entire row 
df.dropna(subset=["price"], axis = 0, inplace= True)
#axis = 0 drop the entire row
#axis = 1 drop the entire column

# %%
df.describe(include ="all")
# Out:
#          symboling normalized-losses    make fuel-type aspiration  \
# count   201.000000               164     201       201        201
# unique         NaN                51      22         2          2
# top            NaN               161  toyota       gas        std
# freq           NaN                11      32       181        165
# mean      0.840796               NaN     NaN       NaN        NaN
# std       1.254802               NaN     NaN       NaN        NaN
# min      -2.000000               NaN     NaN       NaN        NaN
# 25%       0.000000               NaN     NaN       NaN        NaN
# 50%       1.000000               NaN     NaN       NaN        NaN
# 75%       2.000000               NaN     NaN       NaN        NaN
# max       3.000000               NaN     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# count           199        201          201             201  201.000000  ...
# ...

# %%
#becuase nan is treated as srt we use astype('float'); can ignore axis = 0 
#using mean instead of missing values here 
avg_horsepower = df['horsepower'].astype('float').mean(axis=0)
print("Average horsepower:", avg_horsepower)
df['horsepower'].replace(np.nan, avg_horsepower, inplace=True)

# %%
# find the mode
df['num-of-doors'].value_counts().idxmax()
# Out:
# 'four'

# %%
avg_norm_loss = df["normalized-losses"].astype("float").mean(axis=0)

df["normalized-losses"].replace(np.nan, avg_norm_loss, inplace=True)

# %%
#change the data format 
df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")
df[["normalized-losses"]] = df[["normalized-losses"]].astype("int")
df[["price"]] = df[["price"]].astype("float")
df[["peak-rpm"]] = df[["peak-rpm"]].astype("float")

# %%
#after droping rows with missing values it is better to reset index 
# simply drop whole row with NaN in "price" column
df.dropna(subset=["price"], axis=0, inplace=True)

# reset index, because we droped two rows
df.reset_index(drop=True, inplace=True)

# %%
# there are some missing values for normalized losses so let's relapce them with the mean of that column 
mean = df['normalized-losses'].mean()

# %%
df['normalized-losses']=pd.to_numeric(df['normalized-losses'], errors='coerce')

# %%
mean = df['normalized-losses'].mean()
df['normalized-losses'].replace(np.nan,mean)
# Out:
# 0      122.0
# 1      122.0
# 2      122.0
# 3      164.0
# 4      164.0
#        ...
# 200     95.0
# 201     95.0
# 202     95.0
# 203     95.0
# 204     95.0
# Name: normalized-losses, Length: 201, dtype: float64

# %%
df['price']= df['price'].astype("int")

# %% [markdown]
# Data Normalization
#
# simple feature scaling: xnew = xold / xmax --> gives 0 to 1
#
# min-max normalization: xnew = (xold - x min) / (xmax - xmin) --> fives 0 to 1
#
# z score: xnew = xold - mu / sigma --> typicaly score will range from -3 and +3

# %%
# simple feature scaling 
df['variable']= df['variable'] / df['variable'].max()

# %%
# min-max normalization
df['variable'] = (df['variable'] - df['variable'].min()) / (df['variable'].max() - df['variable'].min())

# %%
# z-score
df['variable'] = (df['variable'] - df['variable'].mean()) / df['variable'].std()

# %%
#binning
np.linspace(2,10,4)
# Out:
# array([ 2.        ,  4.66666667,  7.33333333, 10.        ])

# %%
df['horsepower'].nunique()
# Out:
# 58

# %%
#we first create an array for bins 
bins = np.linspace(min(df['price']),max(df['price']), 4)
#then we make a list for groups 
group_names = ['low', 'med', 'high']

# %%
df['price-binned'] = pd.cut(df['price'], bins, labels=group_names, include_lowest=True)

# %%
df[['price','price-binned']]
# Out:
#      price price-binned
# 0    13495          low
# 1    16500          low
# 2    16500          low
# 3    13950          low
# 4    17450          low
# ..     ...          ...
# 200  16845          low
# 201  19045          med
# 202  21485          med
# 203  22470          med
# 204  22625          med
#
# [201 rows x 2 columns]

# %%
#changing categorical vriables to dummy variables or indicator variables 
# we use dummy variables in regression 
pd.get_dummies(df['fuel-type'])
# Out:
#      diesel  gas
# 0         0    1
# 1         0    1
# 2         0    1
# 3         0    1
# 4         0    1
# ..      ...  ...
# 200       0    1
# 201       0    1
# 202       0    1
# 203       1    0
# 204       0    1
#
# [201 rows x 2 columns]
