# %% [markdown]
# # Nnatural and Technological Disasters in Iran
# *Soheil Shapouri*

# %% [markdown]
# This is a quick look at natural and technogical disasters in Asia based on data from EM-DAT dataset and in Jupyter notebook format.

# %%
#importing libraries 

import matplotlib.pyplot as plt #visualization
import pandas as pd             #reading files 
import numpy as np 
import csv
import seaborn as sns           #visualization
# %matplotlib inline     
sns.set(color_codes=True)

# %%
df = pd.read_excel("C:\\Users\\17063\\Downloads\\EMDAT_03_06_2023.xlsx")
# Out:
#           Dis No  Year   Seq Glide Disaster Group Disaster Subgroup  \
# 0  1900-9001-IND  1900  9001   NaN        Natural    Climatological
# 1  1904-0003-BGD  1904     3   NaN        Natural    Meteorological
# 2  1905-0003-IND  1905     3   NaN        Natural       Geophysical
# 3  1906-0015-HKG  1906    15   NaN        Natural    Meteorological
# 4  1907-0006-CHN  1907     6   NaN        Natural       Geophysical
#
#   Disaster Type  Disaster Subtype Disaster Subsubtype Event Name  ...  \
# 0       Drought           Drought                 NaN        NaN  ...
# 1         Storm  Tropical cyclone                 NaN        NaN  ...
# 2    Earthquake   Ground movement                 NaN        NaN  ...
# 3         Storm  Tropical cyclone                 NaN        NaN  ...
# 4    Earthquake   Ground movement                 NaN        NaN  ...
#
#   Reconstruction Costs, Adjusted ('000 US$) Insured Damages ('000 US$)  \
# ...

# %%
#check the data

df.head(5) #Display the top 5 rows to check the data
# Out:
# Disaster Number                              10725
# Year                                         10725
# Disaster Group                               10725
# Disaster Subgroup                            10725
# Disaster Type                                10725
# Disaster Subtype                              9437
# Disaster Subsubtype                            340
# Event Name                                    3429
# Country                                      10725
# ISO                                          10725
# Region                                       10725
# Continent                                    10725
# Location                                      9916
# Origin                                        1757
# Associated Dis                                1499
# Associated Dis2                                330
# OFDA Response                                  589
# Appeal                                        2455
# ...

# %%
df.dtypes # check the type of varibales
# Out:
# Disaster Number                              10725
# Year                                         10725
# Disaster Group                               10725
# Disaster Subgroup                            10725
# Disaster Type                                10725
# Disaster Subtype                              9437
# Disaster Subsubtype                            340
# Event Name                                    3429
# Country                                      10725
# ISO                                          10725
# Region                                       10725
# Continent                                    10725
# Location                                      9916
# Origin                                        1757
# Associated Dis                                1499
# Associated Dis2                                330
# OFDA Response                                  589
# Appeal                                        2455
# ...

# %%
df.count()      # Used to count the number of rows
# Out:
# Disaster Number                              10725
# Year                                         10725
# Disaster Group                               10725
# Disaster Subgroup                            10725
# Disaster Type                                10725
# Disaster Subtype                              9437
# Disaster Subsubtype                            340
# Event Name                                    3429
# Country                                      10725
# ISO                                          10725
# Region                                       10725
# Continent                                    10725
# Location                                      9916
# Origin                                        1757
# Associated Dis                                1499
# Associated Dis2                                330
# OFDA Response                                  589
# Appeal                                        2455
# ...

# %%
#check missing values
print(df.isnull().sum())
# Out:
# Disaster Number                                  0
# Year                                             0
# Disaster Group                                   0
# Disaster Subgroup                                0
# Disaster Type                                    0
# Disaster Subtype                              1288
# Disaster Subsubtype                          10385
# Event Name                                    7296
# Country                                          0
# ISO                                              0
# Region                                           0
# Continent                                        0
# Location                                       809
# Origin                                        8968
# Associated Dis                                9226
# Associated Dis2                              10395
# OFDA Response                                10136
# Appeal                                        8270
# ...

# %%
#check the data
df.tail(5)
# Out:
#               Dis No  Year  Seq           Glide Disaster Group  \
# 10720  2023-0054-SYR  2023   54  EQ-2023-000015        Natural
# 10721  2023-0107-SYR  2023  107             NaN        Natural
# 10722  2023-0034-SYR  2023   34             NaN  Technological
# 10723  2023-0035-THA  2023   35             NaN  Technological
# 10724  2023-0107-TUR  2023  107             NaN        Natural
#
#       Disaster Subgroup           Disaster Type Disaster Subtype  \
# 10720       Geophysical              Earthquake  Ground movement
# 10721       Geophysical              Earthquake  Ground movement
# 10722     Technological  Miscellaneous accident         Collapse
# 10723     Technological      Transport accident             Road
# 10724       Geophysical              Earthquake  Ground movement
#
#       Disaster Subsubtype Event Name  ...  \
# 10720                 NaN        NaN  ...
# 10721                 NaN        NaN  ...
# 10722                 NaN   Building  ...
# ...

# %%
#drop columns that you don't want 
to_drop = ['Seq',
           'CPI',
           'Glide',
           'Admin1 Code',
           'Admin2 Code',
           'Adm Level',
          'Geo Locations']

# %%
df.drop(to_drop, inplace = True, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8380/1394621881.py in <module>
# ----> 1 df.drop(to_drop, inplace = True, axis = 1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.head(5) # this shows whether I successfully dropped unnecessary columns or not
# Out:
#   Disaster Number  Year Disaster Group Disaster Subgroup Disaster Type  \
# 0   1900-9001-IND  1900        Natural    Climatological       Drought
# 1   1904-0003-BGD  1904        Natural    Meteorological         Storm
# 2   1905-0003-IND  1905        Natural       Geophysical    Earthquake
# 3   1906-0015-HKG  1906        Natural    Meteorological         Storm
# 4   1907-0006-CHN  1907        Natural       Geophysical    Earthquake
#
#    Disaster Subtype Disaster Subsubtype Event Name     Country  ISO  ...  \
# 0           Drought                 NaN        NaN       India  IND  ...
# 1  Tropical cyclone                 NaN        NaN  Bangladesh  BGD  ...
# 2   Ground movement                 NaN        NaN       India  IND  ...
# 3  Tropical cyclone                 NaN        NaN   Hong Kong  HKG  ...
# 4   Ground movement                 NaN        NaN       China  CHN  ...
#
#   No Injured No Affected No Homeless Total Affected  \
# ...

# %%
#change column/varibale names 
new_names = {'Dis No' : 'Disaster Number'}
df.rename(columns =new_names, inplace = True)

# %%
#replacing values 
replace_values = {'Iran (Islamic Republic of)' : 'Iran'}
df = df.replace({"Country" : replace_values})

# %%
#check outliers
sns.boxplot(x=df['Total Affected'])
# Out:
# <AxesSubplot:xlabel='Total Affected'>

# %%
#check outliers
sns.boxplot(x = df['Total Deaths'])
# Out:
# <AxesSubplot:xlabel='Total Deaths'>

# %% [markdown]
# 1900-2023| Natural Disasters | Technological Disasters
# -----|----------------|--------------
#  Killed   |               |
#  Injured   |               |
#  Affected   |              |

# %% [markdown]
# emdat.be

# %% [markdown]
# <a href="https://github.com/soheilshapouri">GitHub</a>
